# %% [markdown]
# Code <span class="caret"></span>
#
# -   <a href="#" id="rmd-show-all-code">Show All Code</a>
# -   <a href="#" id="rmd-hide-all-code">Hide All Code</a>
# -
# -   <a href="#" id="rmd-download-source">Download Rmd</a>
#
# # R Notebook
#
# ``` r
# #                    **Analysing Trend and Seasonal Variation Notebook - 1**
# ```
#
# ``` r
# # Install and Load required packages
# install.packages("tidyverse")
# library(tidyverse)
# library(datasets)
# ```
#
# ``` r
# # Consider the Us Air passenger data set
# data("AirPassengers")
# data.air = AirPassengers
# data.air
# ```
#
#          Jan Feb Mar Apr May Jun Jul Aug Sep Oct Nov Dec
#     1949 112 118 132 129 121 135 148 148 136 119 104 118
#     1950 115 126 141 135 125 149 170 170 158 133 114 140
#     1951 145 150 178 163 172 178 199 199 184 162 146 166
#     1952 171 180 193 181 183 218 230 242 209 191 172 194
#     1953 196 196 236 235 229 243 264 272 237 211 180 201
#     1954 204 188 235 227 234 264 302 293 259 229 203 229
#     1955 242 233 267 269 270 315 364 347 312 274 237 278
#     1956 284 277 317 313 318 374 413 405 355 306 271 306
#     1957 315 301 356 348 355 422 465 467 404 347 305 336
#     1958 340 318 362 348 363 435 491 505 404 359 310 337
#     1959 360 342 406 396 420 472 548 559 463 407 362 405
#     1960 417 391 419 461 472 535 622 606 508 461 390 432
#
# ``` r
# # Checking the type of the data (Class)
# class(data.air)
# ```
#
#     [1] "ts"
#
# ``` r
# # ts: 'Time Series Data'
# ```
#
# ``` r
# # Checking basic properties of data.air
# start(data.air) # January 1940
# ```
#
#     [1] 1949    1
#
# ``` r
# end(data.air) # December 1960
# ```
#
#     [1] 1960   12
#
# ``` r
# frequency(data.air) # Gives number of months
# ```
#
#     [1] 12
#
# ``` r
# summary(data.air) # Provides summary statistics
# ```
#
#        Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       104.0   180.0   265.5   280.3   360.5   622.0
#
# ``` r
# # Analyze trend of Air passengers from 1940 to 1960
# plot(data.air, ylab = "Number of Passengers(in 1000s)", col = 'red')
# ```
#
# ![](data:image/png;base64,...)
#
# ``` r
# # Removing Seasonality from data.air
# layout(1:2) # To get two plot in same area
# plot(aggregate(data.air)) # This is the trend component
# boxplot(data.air ~ cycle(data.air)) # Cyclic component
# ```
#
# ![](data:image/png;base64,...)
#
# ...
